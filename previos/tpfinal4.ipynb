# %%
import pandas as pd
import numpy as np

# %%
#Cargar los datos
df = pd.read_csv('data/precios-historicos.csv')

# %%
df.head()
# Out:
#    idempresa               empresa        direccion          localidad  \
# 0       1376  10 DE SETIEMBRE S.A.  Av. Mosconi 299  LOMAS DEL MIRADOR
# 1       1376  10 DE SETIEMBRE S.A.  Av. Mosconi 299  LOMAS DEL MIRADOR
# 2       1376  10 DE SETIEMBRE S.A.  Av. Mosconi 299  LOMAS DEL MIRADOR
# 3       1376  10 DE SETIEMBRE S.A.  Av. Mosconi 299  LOMAS DEL MIRADOR
# 4       1376  10 DE SETIEMBRE S.A.  Av. Mosconi 299  LOMAS DEL MIRADOR
#
#       provincia  idproducto         producto  idtipohorario tipohorario  \
# 0  BUENOS AIRES          19  Gas Oil Grado 2              2      Diurno
# 1  BUENOS AIRES          19  Gas Oil Grado 2              3    Nocturno
# 2  BUENOS AIRES          19  Gas Oil Grado 2              2      Diurno
# 3  BUENOS AIRES          19  Gas Oil Grado 2              3    Nocturno
# 4  BUENOS AIRES          19  Gas Oil Grado 2              2      Diurno
#
#    precio    fecha_vigencia  idempresabandera empresabandera    latitud  \
# ...

# %%
# Valores unicos de la columna anio
anios = df['anio'].unique().tolist()

# Ordenar los anios de menor a mayor
anios.sort()

# Imprimir los anios
print(anios)
# Out:
# [1, 2, 3, 4, 5, 6, 7, 8, 17, 18, 19, 22, 23, 120, 201, 202, 207, 1157, 1218, 2001, 2002, 2003, 2004, 2005, 2006, 2007, 2008, 2009, 2010, 2011, 2012, 2013, 2014, 2015, 2016, 2017, 2018, 2019, 2020, 2021, 2022, 2023, 2024, 2025, 2027, 2028, 2029, 2030, 2031, 2044, 3201, 4201, 6202, 7202, 8202, 9202, 9920]

# %%
# Filtro solo los anios comprendidos entre 2001 y 2024
df = df[(df['anio'] >= 2001) & (df['anio'] <= 2024)]

# %%
df.head()
# Out:
#    idempresa               empresa        direccion          localidad  \
# 0       1376  10 DE SETIEMBRE S.A.  Av. Mosconi 299  LOMAS DEL MIRADOR
# 1       1376  10 DE SETIEMBRE S.A.  Av. Mosconi 299  LOMAS DEL MIRADOR
# 2       1376  10 DE SETIEMBRE S.A.  Av. Mosconi 299  LOMAS DEL MIRADOR
# 3       1376  10 DE SETIEMBRE S.A.  Av. Mosconi 299  LOMAS DEL MIRADOR
# 4       1376  10 DE SETIEMBRE S.A.  Av. Mosconi 299  LOMAS DEL MIRADOR
#
#       provincia  idproducto         producto  idtipohorario tipohorario  \
# 0  BUENOS AIRES          19  Gas Oil Grado 2              2      Diurno
# 1  BUENOS AIRES          19  Gas Oil Grado 2              3    Nocturno
# 2  BUENOS AIRES          19  Gas Oil Grado 2              2      Diurno
# 3  BUENOS AIRES          19  Gas Oil Grado 2              3    Nocturno
# 4  BUENOS AIRES          19  Gas Oil Grado 2              2      Diurno
#
#    precio    fecha_vigencia  idempresabandera empresabandera    latitud  \
# ...

# %%
# Valores unicos de la columna anio
anios = df['anio'].unique().tolist()

# Ordenar los anios de menor a mayor
anios.sort()

# Imprimir los anios
print(anios)
# Out:
# [2001, 2002, 2003, 2004, 2005, 2006, 2007, 2008, 2009, 2010, 2011, 2012, 2013, 2014, 2015, 2016, 2017, 2018, 2019, 2020, 2021, 2022, 2023, 2024]

# %%
# Crear la columna 'fecha' combinando 'anio' y 'mes' como una cadena
df['fecha'] = pd.to_datetime(df['anio'].astype(str) + '-' + df['mes'].astype(str) + '-01')

# %%
df.head()
# Out:
#    idempresa               empresa        direccion          localidad  \
# 0       1376  10 DE SETIEMBRE S.A.  Av. Mosconi 299  LOMAS DEL MIRADOR
# 1       1376  10 DE SETIEMBRE S.A.  Av. Mosconi 299  LOMAS DEL MIRADOR
# 2       1376  10 DE SETIEMBRE S.A.  Av. Mosconi 299  LOMAS DEL MIRADOR
# 3       1376  10 DE SETIEMBRE S.A.  Av. Mosconi 299  LOMAS DEL MIRADOR
# 4       1376  10 DE SETIEMBRE S.A.  Av. Mosconi 299  LOMAS DEL MIRADOR
#
#       provincia  idproducto         producto  idtipohorario tipohorario  \
# 0  BUENOS AIRES          19  Gas Oil Grado 2              2      Diurno
# 1  BUENOS AIRES          19  Gas Oil Grado 2              3    Nocturno
# 2  BUENOS AIRES          19  Gas Oil Grado 2              2      Diurno
# 3  BUENOS AIRES          19  Gas Oil Grado 2              3    Nocturno
# 4  BUENOS AIRES          19  Gas Oil Grado 2              2      Diurno
#
#    precio    fecha_vigencia  idempresabandera empresabandera    latitud  \
# ...

# %%
# Establecer la columna 'fecha' como índice
df.set_index('fecha', inplace=True)

# %%
df.head()
# Out:
#             idempresa               empresa        direccion  \
# fecha
# 2024-04-01       1376  10 DE SETIEMBRE S.A.  Av. Mosconi 299
# 2024-04-01       1376  10 DE SETIEMBRE S.A.  Av. Mosconi 299
# 2024-07-01       1376  10 DE SETIEMBRE S.A.  Av. Mosconi 299
# 2024-07-01       1376  10 DE SETIEMBRE S.A.  Av. Mosconi 299
# 2024-08-01       1376  10 DE SETIEMBRE S.A.  Av. Mosconi 299
#
#                     localidad     provincia  idproducto         producto  \
# fecha
# 2024-04-01  LOMAS DEL MIRADOR  BUENOS AIRES          19  Gas Oil Grado 2
# 2024-04-01  LOMAS DEL MIRADOR  BUENOS AIRES          19  Gas Oil Grado 2
# 2024-07-01  LOMAS DEL MIRADOR  BUENOS AIRES          19  Gas Oil Grado 2
# 2024-07-01  LOMAS DEL MIRADOR  BUENOS AIRES          19  Gas Oil Grado 2
# 2024-08-01  LOMAS DEL MIRADOR  BUENOS AIRES          19  Gas Oil Grado 2
#
#             idtipohorario tipohorario  precio    fecha_vigencia  \
# fecha
# 2024-04-01              2      Diurno   985.0  01/04/2024 10:11
# ...

# %%
# Elimino las columnas anio y mes
df.drop(columns=['anio', 'mes'], inplace=True)

# %%
df.head()
# Out:
#             idempresa               empresa        direccion  \
# fecha
# 2024-04-01       1376  10 DE SETIEMBRE S.A.  Av. Mosconi 299
# 2024-04-01       1376  10 DE SETIEMBRE S.A.  Av. Mosconi 299
# 2024-07-01       1376  10 DE SETIEMBRE S.A.  Av. Mosconi 299
# 2024-07-01       1376  10 DE SETIEMBRE S.A.  Av. Mosconi 299
# 2024-08-01       1376  10 DE SETIEMBRE S.A.  Av. Mosconi 299
#
#                     localidad     provincia  idproducto         producto  \
# fecha
# 2024-04-01  LOMAS DEL MIRADOR  BUENOS AIRES          19  Gas Oil Grado 2
# 2024-04-01  LOMAS DEL MIRADOR  BUENOS AIRES          19  Gas Oil Grado 2
# 2024-07-01  LOMAS DEL MIRADOR  BUENOS AIRES          19  Gas Oil Grado 2
# 2024-07-01  LOMAS DEL MIRADOR  BUENOS AIRES          19  Gas Oil Grado 2
# 2024-08-01  LOMAS DEL MIRADOR  BUENOS AIRES          19  Gas Oil Grado 2
#
#             idtipohorario tipohorario  precio    fecha_vigencia  \
# fecha
# 2024-04-01              2      Diurno   985.0  01/04/2024 10:11
# ...

# %%
# Vemos si hay valores nulos
df.isnull().sum()
# Out:
# idempresa              0
# empresa                0
# direccion              0
# localidad              0
# provincia              0
# idproducto             0
# producto               0
# idtipohorario          0
# tipohorario            0
# precio                 0
# fecha_vigencia         0
# idempresabandera       0
# empresabandera         0
# latitud             1536
# longitud            1536
# geojson             1536
# dtype: int64

# %%
# Elimino la columna idempresa, empresa, direccion, localidad y provincia
df.drop(columns=['idempresa', 'empresa', 'direccion', 'localidad', 'provincia'], inplace=True)

# %%
# Elimino la columna idproducto
df.drop(columns=['idproducto'], inplace=True)

# %%
# Elimino la columna idtipohorario y tipohorario
df.drop(columns=['idtipohorario', 'tipohorario'], inplace=True)

# %%
# Elimino las fecha_vigencia, idempresabandera, empresabandera
df.drop(columns=['fecha_vigencia', 'idempresabandera', 'empresabandera'], inplace=True)

# %%
# Elimino las columnas latitud, longitud y geojson
df.drop(columns=['latitud', 'longitud', 'geojson'], inplace=True)

# %%
df.head()
# Out:
#                    producto  precio
# fecha
# 2024-04-01  Gas Oil Grado 2   985.0
# 2024-04-01  Gas Oil Grado 2   985.0
# 2024-07-01  Gas Oil Grado 2  1080.0
# 2024-07-01  Gas Oil Grado 2  1080.0
# 2024-08-01  Gas Oil Grado 2  1108.0

# %%
# Extraigo los valores unicos de la columna producto
df['producto'].unique()
# Out:
# array(['Gas Oil Grado 2', 'Gas Oil Grado 3', 'GNC',
#        'Nafta (premium) de más de 95 Ron',
#        'Nafta (súper) entre 92 y 95 Ron'], dtype=object)

# %%
# Filtro solo los productos = 'Nafta (premium) de más de 95 Ron'
df_nafta_premium = df[df['producto'] == 'Nafta (premium) de más de 95 Ron'].copy()
df_nafta_premium.shape
# Out:
# (672443, 2)

# %%
df_nafta_premium.head()
# Out:
#                                     producto  precio
# fecha
# 2024-04-01  Nafta (premium) de más de 95 Ron  1158.0
# 2024-04-01  Nafta (premium) de más de 95 Ron  1158.0
# 2024-07-01  Nafta (premium) de más de 95 Ron  1289.0
# 2024-07-01  Nafta (premium) de más de 95 Ron  1289.0
# 2024-08-01  Nafta (premium) de más de 95 Ron  1320.0

# %%
# Elimino la columna producto
df_nafta_premium.drop(columns=['producto'], inplace=True)

# %%
df_nafta_premium.head()
# Out:
#             precio
# fecha
# 2024-04-01  1158.0
# 2024-04-01  1158.0
# 2024-07-01  1289.0
# 2024-07-01  1289.0
# 2024-08-01  1320.0

# %%
# dimension del dataframe
df_nafta_premium.shape
# Out:
# (672443, 1)

# %%
# Extraigo solo las filas comprendidas entre 2020-01-01 y 2023-12-31
#df_nafta_premium = df_nafta_premium[(df_nafta_premium.index >= '2020-01-01') & (df_nafta_premium.index <= '2023-12-31')]
#df_nafta_premium = df_nafta_premium[(df_nafta_premium.index >= '2021-01-01') & (df_nafta_premium.index <= '2023-12-31')]

# %%
df_nafta_premium.shape
# Out:
# (672443, 1)

# %%
# Cálculo de promedios mensuales
df_nafta_premium.resample(rule='ME').mean()
# Out:
#                  precio
# fecha
# 2001-10-31    44.080000
# 2001-11-30          NaN
# 2001-12-31          NaN
# 2002-01-31          NaN
# 2002-02-28          NaN
# ...                 ...
# 2024-08-31  1306.047791
# 2024-09-30  1359.060020
# 2024-10-31  1345.950737
# 2024-11-30  1385.662328
# 2024-12-31  1422.622057
#
# [279 rows x 1 columns]

# %%
df_nafta_premium.resample('ME').mean().plot.bar(title='Ventas promedio por mes en 2020 a 2024');

# %%
# Cálculo de promedios mensuales en un nuevo dataframe
df_promedio_mensual = df_nafta_premium.groupby('fecha')['precio'].mean().reset_index()

# %%
df_promedio_mensual.set_index('fecha', inplace=True)
# Ordenar el índice cronológicamente (importante para series temporales)
df_promedio_mensual.sort_index(inplace=True)

# %%
df_promedio_mensual.plot();

# %%
df_promedio_mensual.head()
# Out:
#              precio
# fecha
# 2001-10-01    44.08
# 2002-03-01  1121.50
# 2002-07-01    23.49
# 2003-11-01   353.20
# 2004-12-01    29.69

# %%
df_promedio_mensual.shape
# Out:
# (113, 1)

# %%
import scipy.stats
import pylab
import matplotlib.pyplot as plt

# %%
# Grafico el qqplot
scipy.stats.probplot(df_promedio_mensual.precio, plot=pylab)
plt.title("QQ Plot", size = 24)
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
import statsmodels.graphics.tsaplots as sgt 
import statsmodels.tsa.stattools as sts 
from statsmodels.tsa.seasonal import seasonal_decompose

import statsmodels.graphics.tsaplots as sgt
from statsmodels.tsa.arima_model import ARIMA
from statsmodels.tsa.arima.model import ARIMA
from scipy.stats.distributions import chi2
import statsmodels.tsa.stattools as sts

# %% [markdown]
# ### Prueba de estacionariedad

# %% [markdown]
# #### Prueba de Dickey-Fuller aumentada (ADF)

# %%
sts.adfuller(df_promedio_mensual['precio'])
# Out:
# (2.0627836742482035,
#  0.9987491802945824,
#  2,
#  110,
#  {'1%': -3.4912451337340342,
#   '5%': -2.8881954545454547,
#   '10%': -2.5809876033057852},
#  954.674652184767)

# %% [markdown]
# Tatare de hacerla estacionaria

# %%
import statsmodels.graphics.tsaplots as sgt 
import statsmodels.tsa.stattools as sts 
from statsmodels.tsa.seasonal import seasonal_decompose

import statsmodels.graphics.tsaplots as sgt
from statsmodels.tsa.arima_model import ARIMA
from statsmodels.tsa.arima.model import ARIMA
from scipy.stats.distributions import chi2
import statsmodels.tsa.stattools as sts

# %%
def check_stationarity(series, name=""):
    result = sts.adfuller(series.dropna())
    print(f'Prueba ADF para {name}:')
    print(f'Estadístico: {result[0]:.4f}')
    print(f'p-valor: {result[1]:.4f}')
    print(f'Valores críticos:')
    for key, value in result[4].items():
        print(f'   {key}: {value:.4f}')
    
    # Interpretar resultado
    if result[1] <= 0.05:
        print(f"Conclusión: La serie {name} es estacionaria (p-valor <= 0.05)")
    else:
        print(f"Conclusión: La serie {name} no es estacionaria (p-valor > 0.05)")
    print("-" * 50)
    return result[1] <= 0.05

# %%
# Función para graficar series
def plot_series(original, transformed, title="Comparación de Series"):
    plt.figure(figsize=(12, 6))
    plt.subplot(211)
    plt.plot(original)
    plt.title("Serie Original")
    plt.subplot(212)
    plt.plot(transformed, color='red')
    plt.title(title)
    plt.tight_layout()
    plt.show()

# %%
# Verificar la serie original
print("ANÁLISIS DE LA SERIE ORIGINAL")
is_stationary = check_stationarity(df_promedio_mensual, "original")
# Out:
# ANÁLISIS DE LA SERIE ORIGINAL
# Prueba ADF para original:
# Estadístico: 2.0628
# p-valor: 0.9987
# Valores críticos:
#    1%: -3.4912
#    5%: -2.8882
#    10%: -2.5810
# Conclusión: La serie original no es estacionaria (p-valor > 0.05)
# --------------------------------------------------

# %%
# 1. DIFERENCIACIÓN
print("\n1. MÉTODO DE DIFERENCIACIÓN")
# Primera diferencia
diff1 = df_promedio_mensual.diff().dropna()
is_stationary_diff1 = check_stationarity(diff1, "primera diferencia")
plot_series(df_promedio_mensual, diff1, "Primera Diferencia")
# Out:
# 1. MÉTODO DE DIFERENCIACIÓN
# Prueba ADF para primera diferencia:
# Estadístico: -4.3573
# p-valor: 0.0004
# Valores críticos:
#    1%: -3.4918
#    5%: -2.8884
#    10%: -2.5811
# Conclusión: La serie primera diferencia es estacionaria (p-valor <= 0.05)
# --------------------------------------------------

# %%
alto
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[45], line 1
# ----> 1 alto
#
# NameError: name 'alto' is not defined

# %%
# Si la primera diferencia no es suficiente, intentar con la segunda
if not is_stationary_diff1:
    diff2 = diff1.diff().dropna()
    is_stationary_diff2 = check_stationarity(diff2, "segunda diferencia")
    plot_series(df_promedio_mensual, diff2, "Segunda Diferencia")

# %%
# 2. TRANSFORMACIONES MATEMÁTICAS
print("\n2. TRANSFORMACIONES MATEMÁTICAS")

# Transformación logarítmica (solo si todos los valores son positivos)
if (df_promedio_mensual['precio'] > 0).all():
    log_transform = np.log(df_promedio_mensual['precio'])
    is_stationary_log = check_stationarity(log_transform, "logarítmica")
    plot_series(df_promedio_mensual['precio'], log_transform, "Transformación Logarítmica")
    
    # Si la transformación logarítmica no es suficiente, probar log + diferenciación
    if not is_stationary_log:
        log_diff = log_transform.diff().dropna()
        is_stationary_log_diff = check_stationarity(log_diff, "logarítmica + diferencia")
        plot_series(log_transform, log_diff, "Logarítmica + Primera Diferencia")
else:
    print("La serie contiene valores no positivos, omitiendo transformación logarítmica")

# Transformación de raíz cuadrada (solo si todos los valores son positivos)
if (df_promedio_mensual['precio'] > 0).all():
    sqrt_transform = np.sqrt(df_promedio_mensual['precio'])
    is_stationary_sqrt = check_stationarity(sqrt_transform, "raíz cuadrada")
    plot_series(df_promedio_mensual['precio'], sqrt_transform, "Transformación Raíz Cuadrada")
else:
    print("La serie contiene valores no positivos, omitiendo transformación de raíz cuadrada")

# Transformación Box-Cox (solo para valores positivos)
if (df['precio'] > 0).all():
    from scipy import stats
    # Encontrar el lambda óptimo para Box-Cox
    boxcox_transform, lambda_value = stats.boxcox(df_promedio_mensual['precio'])
    boxcox_transform = pd.Series(boxcox_transform, index=df.index)
    print(f"Lambda óptimo para Box-Cox: {lambda_value:.4f}")
    is_stationary_boxcox = check_stationarity(boxcox_transform, "Box-Cox")
    plot_series(df_promedio_mensual['precio'], boxcox_transform, f"Transformación Box-Cox (lambda={lambda_value:.4f})")
else:
    print("La serie contiene valores no positivos, omitiendo transformación Box-Cox")

# %%
# 3. SUSTRACCIÓN DE TENDENCIA O ESTACIONALIDAD
print("\n3. SUSTRACCIÓN DE TENDENCIA O ESTACIONALIDAD")

# Descomposición de series temporales
try:
    # Determinar frecuencia de datos (ajustar según tu serie)
    # Para datos diarios: freq=7, para datos mensuales: freq=12, etc.
    # Si los datos no tienen una frecuencia conocida, se puede usar un valor estimado
    freq = 12  # Ajustar según tu serie
    
    decomposition = seasonal_decompose(df_promedio_mensual['precio'], model='additive', period=freq)
    
    # Graficar descomposición
    plt.figure(figsize=(12, 10))
    plt.subplot(411)
    plt.plot(df_promedio_mensual['precio'], label='Original')
    plt.legend(loc='best')
    plt.subplot(412)
    plt.plot(decomposition.trend, label='Tendencia')
    plt.legend(loc='best')
    plt.subplot(413)
    plt.plot(decomposition.seasonal, label='Estacionalidad')
    plt.legend(loc='best')
    plt.subplot(414)
    plt.plot(decomposition.resid, label='Residuos')
    plt.legend(loc='best')
    plt.tight_layout()
    plt.show()
    
    # Serie sin tendencia
    detrended = df_promedio_mensual['precio'] - decomposition.trend
    detrended = detrended.dropna()
    is_stationary_detrended = check_stationarity(detrended, "sin tendencia")
    plot_series(df_promedio_mensual['precio'], detrended, "Serie sin Tendencia")
    
    # Serie sin estacionalidad
    deseasonalized = df_promedio_mensual['precio'] - decomposition.seasonal
    is_stationary_deseasonalized = check_stationarity(deseasonalized, "sin estacionalidad")
    plot_series(df_promedio_mensual['precio'], deseasonalized, "Serie sin Estacionalidad")
    
    # Serie con solo residuos (sin tendencia ni estacionalidad)
    residual = decomposition.resid
    residual = residual.dropna()
    is_stationary_residual = check_stationarity(residual, "residual")
    plot_series(df_promedio_mensual['precio'], residual, "Serie Residual")
    
except Exception as e:
    print(f"Error en la descomposición de la serie: {e}")
    print("Intenta ajustar la frecuencia (period) según tus datos")
    
    # Alternativa: Eliminar tendencia usando regresión lineal
    X = np.arange(len(df_promedio_mensual['precio']))
    y = df_promedio_mensual['precio'].values
    X = np.vstack([X, np.ones(len(X))]).T
    
    # Ajustar modelo de regresión lineal
    from sklearn.linear_model import LinearRegression
    model = LinearRegression()
    model.fit(X[:, 0].reshape(-1, 1), y)
    
    # Predecir tendencia
    trend = model.predict(X[:, 0].reshape(-1, 1))
    
    # Eliminar tendencia
    detrended_linear = df_promedio_mensual['precio'] - trend
    detrended_linear = pd.Series(detrended_linear, index=df_promedio_mensual.index)
    is_stationary_detrended_linear = check_stationarity(detrended_linear, "sin tendencia lineal")
    plot_series(df_promedio_mensual['precio'], detrended_linear, "Serie sin Tendencia Lineal")
